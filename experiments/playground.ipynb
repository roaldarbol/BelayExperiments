# %%
import time
import sys
sys.path.append('..')
from belay import Device, list_devices, UsbSpecifier
from devices.PicoBonn import PicoBonn

# %%
spec = UsbSpecifier(
    vid=11914, 
    pid=5, 
    serial_number='70973D3DE68AC915', 
    manufacturer='Microsoft', 
    location='1-4:x.0')

# %%
with PicoBonn(spec) as pico:
    pico.read_environment()
# Out:
# Temp: 21.53191
# Pressure: 101111.72
# Humidity: 31.99675

# %%
dir(picoB)

# %%
picoB.set_led(False)
# Out:
# Printing from device; turning LED to False.

# %%
picoB.led_off()
picoB.close()
